# %%
import matplotlib.pyplot as plt

# %%
import

# %%
y=[1,3,7,5]
plt.plot(y)

# %%
x=[2,4,6,8]
plt.plot(x,y)

# %%
x=[2,4,6,8]
y=[x*x for x in x]

# %% [markdown]
# ### 문제

# %% [markdown]
# - subplot 을 이용해서 2행 1열 구조 2개씩
# - 4가지 색상 다르게
# - 4가지 스타일 다르게
# - 4가지 마커 서로 다르게
# - 범례표시
# - x,y제목
#
#
#
# x=0부터 5까지 단위1

# %%
import matplotlib.pyplot as plt

# %%
import
